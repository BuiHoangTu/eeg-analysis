# %%
import mne

raw = mne.io.read_raw_edf("../data/S012R01.edf")
raw.info
# Out:
# Extracting EDF parameters from ../data/S012R01.edf...
# Setting channel info structure...
# Creating raw.info structure...
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 80.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
#  subject_info: <subject_info | his_id: X, sex: 0, last_name: X>
# >

# %%
raw.duration
# Out:
# np.float64(61.0)

# %%
raw.ch_names
# Out:
# ['Fc5.',
#  'Fc3.',
#  'Fc1.',
#  'Fcz.',
#  'Fc2.',
#  'Fc4.',
#  'Fc6.',
#  'C5..',
#  'C3..',
#  'C1..',
#  'Cz..',
#  'C2..',
#  'C4..',
#  'C6..',
#  'Cp5.',
#  'Cp3.',
#  'Cp1.',
#  'Cpz.',
#  'Cp2.',
#  'Cp4.',
#  'Cp6.',
#  'Fp1.',
#  'Fpz.',
#  'Fp2.',
#  'Af7.',
#  'Af3.',
#  'Afz.',
#  'Af4.',
#  'Af8.',
#  'F7..',
#  'F5..',
#  'F3..',
#  'F1..',
#  'Fz..',
#  'F2..',
#  'F4..',
#  'F6..',
#  'F8..',
#  'Ft7.',
#  'Ft8.',
#  'T7..',
#  'T8..',
#  'T9..',
#  'T10.',
#  'Tp7.',
#  'Tp8.',
#  'P7..',
#  'P5..',
#  'P3..',
#  'P1..',
#  'Pz..',
#  'P2..',
#  'P4..',
#  'P6..',
#  'P8..',
#  'Po7.',
#  'Po3.',
#  'Poz.',
#  'Po4.',
#  'Po8.',
#  'O1..',
#  'Oz..',
#  'O2..',
#  'Iz..']

# %%
raw.annotations.to_data_frame()
# Out:
#                 onset  duration description
# 0 2009-08-12 16:15:00      60.2          T0
